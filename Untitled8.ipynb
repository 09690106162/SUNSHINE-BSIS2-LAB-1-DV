# %% [markdown]
# <a href="https://colab.research.google.com/github/09690106162/SUNSHINE-BSIS2-LAB-1-DV/blob/main/Untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
from sklearn.decomposition import PCA

# %%
from sklearn.datasets import load_iris

# %%
# Load Iris dataset for demonstration
iris = load_iris()
X = iris.data
y = iris.target

# %%
# Step 1: Standardize the data
X_standardized = (X - np.mean(X, axis=0)) / np.std(X, axis=0)

# %%
# Step 2-4: PCA
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_standardized)

# %%
# Plot original data
plt.figure(figsize=(12, 4))

# %%
plt.subplot(1, 2, 1)
plt.scatter(X[:, 0], X[:, 1], c=y, cmap='viridis', edgecolor='k', s=60)
plt.title('Original Data (2D Projection)')
# Out:
# Text(0.5, 1.0, 'Original Data (2D Projection)')

# %%
# Plot PCA-transformed data
plt.subplot(1, 2, 2)
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y, cmap='viridis', edgecolor='k', s=60)
plt.title('PCA-Transformed Data')

plt.show()
